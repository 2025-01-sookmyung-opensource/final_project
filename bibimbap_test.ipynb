# %% [markdown]
# <a href="https://colab.research.google.com/github/2025-01-sookmyung-opensource/final_project/blob/woojin/bibimbap_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/woojin-devv/final_project.git
# Out:
# Cloning into 'final_project'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 19 (delta 5), reused 12 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 5.90 KiB | 5.90 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !mkdir models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/food/bibimbap.v1i.yolov8.zip" -d /content/
# Out:
# Archive:  /content/drive/MyDrive/food/bibimbap.v1i.yolov8.zip
#   inflating: /content/README.dataset.txt
#   inflating: /content/README.roboflow.txt
#   inflating: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/bibimbap_100_jpg.rf.1c567f22caa0e9d4296e49c6ac981829.jpg
#  extracting: /content/test/images/bibimbap_104_jpg.rf.f184fc45ad20acfaf5139943b40a7c11.jpg
#  extracting: /content/test/images/bibimbap_119_jpg.rf.e132e190cbf372d37db213cb60624263.jpg
#  extracting: /content/test/images/bibimbap_121_jpg.rf.925a9bf051f810047ff9677f87096c5a.jpg
#  extracting: /content/test/images/bibimbap_122_jpg.rf.da28efcfcb358db658aa69516d4d0df9.jpg
#  extracting: /content/test/images/bibimbap_123_jpg.rf.0896839a800f0605f1bfacc8b7bb36d4.jpg
#  extracting: /content/test/images/bibimbap_130_jpg.rf.ef34c3f4a0514a89ef7e65b80d897875.jpg
#  extracting: /content/test/images/bibimbap_136_jpg.rf.5af78be9ed80406d9165e6f98bf568b9.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 131.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# 모델 로드 (원하면 yolov8s.pt 등으로 교체 가능)
model = YOLO("yolov8n.pt")

# 학습 실행
model.train(
    data="/content/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 354MB/s]
# Ultralytics 8.3.151 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
